# %% [markdown]
# ### My first package

# %%
import preprocess_csl as pcsl
text = "This is a sample text for testing the text preprocessing functions. 1"
cleaned_text = pcsl.word_count(text)
print(cleaned_text)
# Out:
# 12

# %%
text = "This is a sample text for testing the text preprocessing functions."
count = pcsl.stop_words_count(text)
print(count)
# Out:
# 5
