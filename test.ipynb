# %% [markdown]
# ### My first package

# %%
import preprocess_csl as pcsl
text = "This is a sample text for testing the text preprocessing functions. 1"
cleaned_text = pcsl.word_count(text)
print(cleaned_text)
# Out:
# 12

# %%
text = "I Love Python programming! It's amazing. 123"
count = pcsl.char_count(text)
print(count)
# Out:
# 38

# %%
import spacy
nlp = spacy.load("en_core_web_sm")
print(nlp.meta["version"])
# Out:
# 3.8.0

# %%
import nltk 
print(nltk.__version__)
# Out:
# 3.9.2

# %%
import bs4
print(bs4.__version__)
# Out:
# 4.13.5
